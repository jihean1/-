# %% [markdown]
# <a href="https://colab.research.google.com/github/jihean1/-/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("안녕하세요")
# Out:
# 안녕하세요

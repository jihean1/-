# %% [markdown]
# <a href="https://colab.research.google.com/github/jihean1/-/blob/main/20260910.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 'hello '
b = 'world'
print(a+b)
print(a*3)
print(a<b)
print('h' in a)
print('wor' not in b)
# Out:
# hello world
# hello hello hello
# True
# True
# False

# %%
a= 'Hello Python'
print(a[0])
print(a[6])
print(a[-1])
# Out:
# H
# P
# n

# %%
a= 'Hello Python'
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
a= input()
print('20', a[0:2],'년',a[2:4],'월',a[4:6],'일')
# Out:
# 100113
# 20 10 년 01 월 13 일
